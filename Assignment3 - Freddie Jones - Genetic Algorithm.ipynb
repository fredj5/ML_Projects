# %%
# Packages and Imports
import numpy as np
from numpy.random import seed
from numpy.random import rand
from numpy.random import randn
import random
import matplotlib.pyplot as plt

# Accuracy score and confusion matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix 

# Backprop optimizer
from tensorflow.keras.optimizers.legacy import Adam 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

# Genetic packages
import pygad.kerasga
import pygad
import pygad.nn
import tensorflow.keras

# Quick fix for an issue where my Jupyter Kernel kept dying
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# /Users/freddiejones/miniconda3/envs/tensorflow/lib/python3.10/site-packages/jax/_src/lib/__init__.py:32: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "

# %%
# Load dataset
wine_data = np.loadtxt('/Users/freddiejones/Desktop/EvolutionaryML/winequality-red.csv', delimiter=',', skiprows=1) # print(wine_data.shape)
np.set_printoptions(formatter={'float': lambda x: '{0:0.2f}'.format(x)})

# %%
# Binary classification transformation
wine_data[wine_data[:, -1] < 5.5, -1] = 0 
wine_data[wine_data[:, -1] >= 5.5, -1] = 1
print(wine_data)
# Out:
# [[7.40 0.70 0.00 ... 0.56 9.40 0.00]
#  [7.80 0.88 0.00 ... 0.68 9.80 0.00]
#  [7.80 0.76 0.04 ... 0.65 9.80 0.00]
#  ...
#  [6.30 0.51 0.13 ... 0.75 11.00 1.00]
#  [5.90 0.65 0.12 ... 0.71 10.20 0.00]
#  [6.00 0.31 0.47 ... 0.66 11.00 1.00]]

# %%
# Balance dataset
np.random.shuffle(wine_data)

# %%
# Split into test and train
thirty_percent = int(0.3 * len(wine_data[:, 0]))

X_test = wine_data[:thirty_percent, :-1] 
Y_test = wine_data[:thirty_percent, -1]

X_train = wine_data[thirty_percent:, 0:-1] 
Y_train = wine_data[thirty_percent:, -1]

# %%
# Normalize wine data
X_train = (X_train - np.mean(X_train, axis=0)) / np.std(X_train, axis=0)
X_test = (X_test - np.mean(X_test, axis=0)) / np.std(X_test, axis=0)

# %%
np.random.seed(0)

# %%
train_accuracy_scores = [] 
test_accuracy_scores = []

# %%
# Fitness determined by binary accuracy score
def fitness_func(solution, sol_idx):
    
    # Globals
    global nn_model, X_train, Y_train
    
    # Model instance and compile
    loss = tensorflow.keras.losses.BinaryCrossentropy()
    nn_model.compile(loss=loss, optimizer=Adam(), metrics=['accuracy'])
    
    # Fit
    history = nn_model.fit(X_train, Y_train, epochs=1)

    # Evaluate the fitness of the solution based on the final accuracy
    accuracy = history.history['accuracy'][-1]
    return accuracy

# %%
# Custom mutation function - exchanges one randomly chosen masked weight with a randomly chosen non-masked weight
def mutation_func(masked_population, nn_model):
    
    # Global variables
    global weights
    
    # Arrays of the indices for unmasked and maked weights
    unmasked_indices = np.where(masked_population == 1)[0]
    masked_indices = np.where(masked_population == 0)[0]
    
    # Choose random unmaked weight and masked weight
    if len(unmasked_indices) > 0 and len(masked_indices) > 0:
        rand_unmasked_idx = np.random.choice(unmasked_indices)
        rand_masked_idx = np.where(masked_population[rand_unmasked_idx] == 0)[0][0]
    
        # Save old value of unmasked weight
        old_value = weights[rand_unmasked_idx].copy()
    
        # Exchange values
        weights[rand_unmasked_idx] = weights[rand_masked_idx]
        weights[rand_masked_idx] = old_value
        nn_model.set_weights(weights)
        
        # Return updated network (along with it's weights)
        return nn_model

# %%
# On-generation function call

# Displays generation number, accuracy score, and fitness score
def callback_generation(ga_instance):   
    
    # Global
    global train_accuracy_scores, test_accuracy_scores
    
    # Print generation number and accuracy score
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Accuracy    = {accuracy}".format(accuracy=fitness_func(solution, sol_idx)))
    print("Fitness = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    
    
    # Train and test scores
    y_pred_tr = nn_model.evaluate(X_train, Y_train, verbose=0)
    train_accuracy = y_pred_tr[1]
    train_accuracy_scores.append(train_accuracy)
    
    y_pred_ts = nn_model.evaluate(X_test, Y_test, verbose=0)
    test_accuracy = y_pred_ts[1]
    test_accuracy_scores.append(test_accuracy)

# %%
# Make neural network model using Sequential keras model
# Define the architecture of your neural network
nn_model = Sequential()
nn_model.add(Dense(11, input_dim = len(X_train[0, :]), activation = 'sigmoid'))
nn_model.add(Dense(22, activation = 'sigmoid'))
nn_model.add(Dense(1, activation = 'sigmoid'))
# Out:
# Metal device set to: Apple M2

# %%
weights = np.concatenate([layer.flatten() for layer in nn_model.get_weights()]) #1-D array for connection weights
masked_population = np.zeros_like(weights) # Same size array filled with zeros for masking
num_unmasked = int(0.1 * weights.size) # 10% of weights unmasked
num_masked = weights.size - num_unmasked # Total number of masked weights
nonzero_indices = np.random.choice(weights.size, size=num_unmasked, replace=False) # Randomly select an unmasked index

# Randomly initialize a masked weights to an unmasked weight
masked_population[nonzero_indices] = np.random.choice(weights[nonzero_indices], size=num_unmasked)

# %%
# Make initial population based on network weights
keras_ga = pygad.kerasga.KerasGA(model=nn_model,
                                 num_solutions=20)

# %%
# Algorithm Parameters/Hyperparameters
# Default parent selection is generational in a PyGad GA
num_parents_mating = 2
num_generations = 10
keep_elitism = 2 # Weak elitism
crossover_type = "uniform" 
crossover_probability = 0.9
mutation_percent_genes= 10
initial_population = keras_ga.population_weights * 2

# %%
# Instantiate genetic algorithm with Parameters/Hyperparameters
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating,
                       initial_population= initial_population,
                       crossover_type= crossover_type,
                       crossover_probability= crossover_probability,
                       fitness_func=fitness_func,
                       mutation_percent_genes= mutation_percent_genes,
                       mutation_type=mutation_func, 
                       keep_elitism=keep_elitism,
                       on_generation=callback_generation)
solution, solution_fitness, sol_idx = ga_instance.best_solution()
# Out:
# 2023-03-12 22:02:17.541612: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 35/35 [==============================] - 0s 4ms/step - loss: 0.7432 - accuracy: 0.4554
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.5536
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6714 - accuracy: 0.6509
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6615 - accuracy: 0.6045
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6535 - accuracy: 0.5964
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6422 - accuracy: 0.6598
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6304 - accuracy: 0.6964
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6166 - accuracy: 0.7107
# 35/35 [==============================] - 0s 4ms/step - loss: 0.6042 - accuracy: 0.7098
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5934 - accuracy: 0.7107
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5823 - accuracy: 0.7161
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5730 - accuracy: 0.7196
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5651 - accuracy: 0.7214
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5590 - accuracy: 0.7268
# 35/35 [==============================] - 0s 4ms/step - loss: 0.5519 - accuracy: 0.7357
# 35/35 [==============================] - 1s 4ms/step - loss: 0.5458 - accuracy: 0.7241
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5420 - accuracy: 0.7286
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5389 - accuracy: 0.7286
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5367 - accuracy: 0.7304
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5345 - accuracy: 0.7330
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5332 - accuracy: 0.7348
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5324 - accuracy: 0.7348
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5310 - accuracy: 0.7375
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5301 - accuracy: 0.7384
# 35/35 [==============================] - 1s 5ms/step - loss: 0.5296 - accuracy: 0.7411
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5289 - accuracy: 0.7402
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5285 - accuracy: 0.7402
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5291 - accuracy: 0.7375
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5275 - accuracy: 0.7393
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5272 - accuracy: 0.7411
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5260 - accuracy: 0.7411
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5258 - accuracy: 0.7411
# 35/35 [==============================] - 1s 5ms/step - loss: 0.5259 - accuracy: 0.7384
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5250 - accuracy: 0.7420
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5247 - accuracy: 0.7437
# 35/35 [==============================] - 1s 5ms/step - loss: 0.5242 - accuracy: 0.7437
# 35/35 [==============================] - 1s 5ms/step - loss: 0.5244 - accuracy: 0.7455
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5243 - accuracy: 0.7402
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5239 - accuracy: 0.7455
# 35/35 [==============================] - 1s 5ms/step - loss: 0.5245 - accuracy: 0.7429

# %%
ga_instance.run()
# Out:
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5236 - accuracy: 0.7464
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5230 - accuracy: 0.7464
# 35/35 [==============================] - 1s 5ms/step - loss: 0.5227 - accuracy: 0.7500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5231 - accuracy: 0.7482
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5226 - accuracy: 0.7464
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5222 - accuracy: 0.7491
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5219 - accuracy: 0.7518
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5218 - accuracy: 0.7446
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5222 - accuracy: 0.7429
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5217 - accuracy: 0.7509
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5217 - accuracy: 0.7500
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5211 - accuracy: 0.7536
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5210 - accuracy: 0.7518
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5212 - accuracy: 0.7545
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5211 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5205 - accuracy: 0.7536
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5208 - accuracy: 0.7491
# 35/35 [==============================] - 0s 5ms/step - loss: 0.5202 - accuracy: 0.7536
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5203 - accuracy: 0.7571
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5202 - accuracy: 0.7545
# 35/35 [==============================] - 1s 5ms/step - loss: 0.5201 - accuracy: 0.7571
# 35/35 [==============================] - 0s 6ms/step - loss: 0.5196 - accuracy: 0.7554
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5197 - accuracy: 0.7563
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5199 - accuracy: 0.7473
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5191 - accuracy: 0.7527
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5194 - accuracy: 0.7580
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5194 - accuracy: 0.7509
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5188 - accuracy: 0.7527
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5187 - accuracy: 0.7527
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5187 - accuracy: 0.7563
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5181 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5189 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5179 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5181 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5182 - accuracy: 0.7518
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5179 - accuracy: 0.7518
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5174 - accuracy: 0.7509
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5182 - accuracy: 0.7536
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5183 - accuracy: 0.7527
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5180 - accuracy: 0.7527
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5182 - accuracy: 0.7509
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5173 - accuracy: 0.7527
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5166 - accuracy: 0.7509
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5168 - accuracy: 0.7563
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5170 - accuracy: 0.7509
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5163 - accuracy: 0.7563
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5173 - accuracy: 0.7491
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5161 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5166 - accuracy: 0.7527
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5160 - accuracy: 0.7500
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5163 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5156 - accuracy: 0.7473
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5153 - accuracy: 0.7527
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5150 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5149 - accuracy: 0.7500
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5155 - accuracy: 0.7491
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5150 - accuracy: 0.7545
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5145 - accuracy: 0.7527
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5154 - accuracy: 0.7536
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5146 - accuracy: 0.7527
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5141 - accuracy: 0.7509
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5143 - accuracy: 0.7509
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5143 - accuracy: 0.7509
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5137 - accuracy: 0.7500
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5141 - accuracy: 0.7518
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5146 - accuracy: 0.7500
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5142 - accuracy: 0.7527
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5132 - accuracy: 0.7500
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5141 - accuracy: 0.7482
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5127 - accuracy: 0.7518
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5127 - accuracy: 0.7527
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5127 - accuracy: 0.7527
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5122 - accuracy: 0.7509
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5124 - accuracy: 0.7482
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5124 - accuracy: 0.7536
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5118 - accuracy: 0.7545
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5120 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5119 - accuracy: 0.7527
# Generation = 1
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5122 - accuracy: 0.7518
# Accuracy    = 0.7517856955528259
# 35/35 [==============================] - 1s 6ms/step - loss: 0.5115 - accuracy: 0.7545
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5115 - accuracy: 0.7518
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5108 - accuracy: 0.7509
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5111 - accuracy: 0.7518
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5104 - accuracy: 0.7509
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5104 - accuracy: 0.7482
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5111 - accuracy: 0.7500
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5103 - accuracy: 0.7527
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5097 - accuracy: 0.7473
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5107 - accuracy: 0.7491
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5101 - accuracy: 0.7527
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5094 - accuracy: 0.7491
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5095 - accuracy: 0.7509
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5092 - accuracy: 0.7482
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5094 - accuracy: 0.7509
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5092 - accuracy: 0.7509
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5090 - accuracy: 0.7554
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5090 - accuracy: 0.7482
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5087 - accuracy: 0.7527
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5086 - accuracy: 0.7509
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5084 - accuracy: 0.7518
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5079 - accuracy: 0.7554
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5077 - accuracy: 0.7536
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5084 - accuracy: 0.7527
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5078 - accuracy: 0.7518
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5077 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5073 - accuracy: 0.7536
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5081 - accuracy: 0.7518
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5069 - accuracy: 0.7527
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5067 - accuracy: 0.7518
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5063 - accuracy: 0.7554
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5061 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5063 - accuracy: 0.7518
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5058 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5059 - accuracy: 0.7536
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5056 - accuracy: 0.7554
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5054 - accuracy: 0.7563
# 35/35 [==============================] - 1s 12ms/step - loss: 0.5053 - accuracy: 0.7580
# Fitness = 0.7580357193946838
# 35/35 [==============================] - 1s 11ms/step - loss: 0.5051 - accuracy: 0.7545
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5058 - accuracy: 0.7509
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5054 - accuracy: 0.7491
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5047 - accuracy: 0.7518
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5050 - accuracy: 0.7554
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5047 - accuracy: 0.7563
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5048 - accuracy: 0.7482
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5041 - accuracy: 0.7563
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5040 - accuracy: 0.7554
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5038 - accuracy: 0.7563
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5044 - accuracy: 0.7509
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5038 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5033 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5031 - accuracy: 0.7580
# 35/35 [==============================] - 1s 11ms/step - loss: 0.5030 - accuracy: 0.7580
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5027 - accuracy: 0.7571
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5030 - accuracy: 0.7563
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5024 - accuracy: 0.7580
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5029 - accuracy: 0.7598
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5024 - accuracy: 0.7589
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5018 - accuracy: 0.7598
# 35/35 [==============================] - 1s 8ms/step - loss: 0.5026 - accuracy: 0.7616
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5016 - accuracy: 0.7571
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5016 - accuracy: 0.7545
# 35/35 [==============================] - 1s 11ms/step - loss: 0.5021 - accuracy: 0.7554
# 35/35 [==============================] - 2s 9ms/step - loss: 0.5012 - accuracy: 0.7536
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5009 - accuracy: 0.7598
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5017 - accuracy: 0.7536
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5007 - accuracy: 0.7589
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5007 - accuracy: 0.7589
# 35/35 [==============================] - 1s 7ms/step - loss: 0.5003 - accuracy: 0.7554
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5009 - accuracy: 0.7563
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5002 - accuracy: 0.7571
# 35/35 [==============================] - 1s 13ms/step - loss: 0.5003 - accuracy: 0.7571
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5018 - accuracy: 0.7518
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4998 - accuracy: 0.7589
# 35/35 [==============================] - 1s 10ms/step - loss: 0.5001 - accuracy: 0.7607
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5002 - accuracy: 0.7527
# Generation = 2
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4993 - accuracy: 0.7563
# Accuracy    = 0.7562500238418579
# 35/35 [==============================] - 1s 9ms/step - loss: 0.5001 - accuracy: 0.7518
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4990 - accuracy: 0.7536
# 35/35 [==============================] - 1s 11ms/step - loss: 0.4989 - accuracy: 0.7580
# 35/35 [==============================] - 1s 11ms/step - loss: 0.4994 - accuracy: 0.7571
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4988 - accuracy: 0.7598
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4991 - accuracy: 0.7545
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4986 - accuracy: 0.7616
# 35/35 [==============================] - 1s 8ms/step - loss: 0.4983 - accuracy: 0.7598
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4987 - accuracy: 0.7598
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4983 - accuracy: 0.7616
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4981 - accuracy: 0.7589
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4976 - accuracy: 0.7607
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4981 - accuracy: 0.7616
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4973 - accuracy: 0.7607
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4976 - accuracy: 0.7589
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4982 - accuracy: 0.7598
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4970 - accuracy: 0.7634
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4975 - accuracy: 0.7643
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4973 - accuracy: 0.7625
# 35/35 [==============================] - 1s 8ms/step - loss: 0.4964 - accuracy: 0.7661
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4961 - accuracy: 0.7580
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4961 - accuracy: 0.7589
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4965 - accuracy: 0.7607
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4958 - accuracy: 0.7616
# 35/35 [==============================] - 2s 12ms/step - loss: 0.4957 - accuracy: 0.7643
# 35/35 [==============================] - 4s 50ms/step - loss: 0.4955 - accuracy: 0.7598
# 35/35 [==============================] - 4s 65ms/step - loss: 0.4963 - accuracy: 0.7598
# 35/35 [==============================] - 4s 50ms/step - loss: 0.4967 - accuracy: 0.7589
# 35/35 [==============================] - 7s 135ms/step - loss: 0.4965 - accuracy: 0.7598
# 35/35 [==============================] - 9s 106ms/step - loss: 0.4957 - accuracy: 0.7634
# 35/35 [==============================] - 3s 11ms/step - loss: 0.4952 - accuracy: 0.7607
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4948 - accuracy: 0.7616
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4958 - accuracy: 0.7554
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4955 - accuracy: 0.7652
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4943 - accuracy: 0.7607
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4950 - accuracy: 0.7580
# 35/35 [==============================] - 1s 8ms/step - loss: 0.4936 - accuracy: 0.7643
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4940 - accuracy: 0.7616
# Fitness = 0.7660714387893677
# 35/35 [==============================] - 1s 11ms/step - loss: 0.4935 - accuracy: 0.7616
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4941 - accuracy: 0.7607
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4937 - accuracy: 0.7616
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4945 - accuracy: 0.7616
# 35/35 [==============================] - 1s 9ms/step - loss: 0.4930 - accuracy: 0.7598
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4934 - accuracy: 0.7616
# 35/35 [==============================] - 1s 11ms/step - loss: 0.4925 - accuracy: 0.7616
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4934 - accuracy: 0.7696
# 35/35 [==============================] - 1s 13ms/step - loss: 0.4921 - accuracy: 0.7616
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4921 - accuracy: 0.7607
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4922 - accuracy: 0.7643
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4916 - accuracy: 0.7607
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4924 - accuracy: 0.7607
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4914 - accuracy: 0.7652
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4911 - accuracy: 0.7607
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4929 - accuracy: 0.7625
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4912 - accuracy: 0.7634
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4913 - accuracy: 0.7643
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4904 - accuracy: 0.7634
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4902 - accuracy: 0.7652
# 35/35 [==============================] - 1s 13ms/step - loss: 0.4904 - accuracy: 0.7652
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4905 - accuracy: 0.7607
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4898 - accuracy: 0.7625
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4895 - accuracy: 0.7643
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4902 - accuracy: 0.7634
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4900 - accuracy: 0.7652
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4895 - accuracy: 0.7616
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4891 - accuracy: 0.7652
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4891 - accuracy: 0.7616
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4895 - accuracy: 0.7625
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4901 - accuracy: 0.7607
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4889 - accuracy: 0.7652
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4883 - accuracy: 0.7652
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4887 - accuracy: 0.7607
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4886 - accuracy: 0.7625
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4879 - accuracy: 0.7643
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4887 - accuracy: 0.7643
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4876 - accuracy: 0.7580
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4877 - accuracy: 0.7598
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4878 - accuracy: 0.7652
# Generation = 3
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4869 - accuracy: 0.7661
# Accuracy    = 0.7660714387893677
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4869 - accuracy: 0.7652
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4864 - accuracy: 0.7607
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4871 - accuracy: 0.7670
# 35/35 [==============================] - 2s 14ms/step - loss: 0.4864 - accuracy: 0.7634
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4862 - accuracy: 0.7679
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4859 - accuracy: 0.7705
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4867 - accuracy: 0.7652
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4857 - accuracy: 0.7661
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4867 - accuracy: 0.7616
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4853 - accuracy: 0.7616
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4854 - accuracy: 0.7670
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4855 - accuracy: 0.7696
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4851 - accuracy: 0.7696
# 35/35 [==============================] - 2s 16ms/step - loss: 0.4849 - accuracy: 0.7625
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4848 - accuracy: 0.7705
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4844 - accuracy: 0.7652
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4845 - accuracy: 0.7616
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4843 - accuracy: 0.7634
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4845 - accuracy: 0.7688
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4836 - accuracy: 0.7661
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4857 - accuracy: 0.7661
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4836 - accuracy: 0.7643
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4831 - accuracy: 0.7643
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4834 - accuracy: 0.7661
# 35/35 [==============================] - 1s 11ms/step - loss: 0.4830 - accuracy: 0.7661
# 35/35 [==============================] - 1s 11ms/step - loss: 0.4830 - accuracy: 0.7634
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4821 - accuracy: 0.7679
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4824 - accuracy: 0.7661
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4819 - accuracy: 0.7634
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4830 - accuracy: 0.7670
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4817 - accuracy: 0.7696
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4818 - accuracy: 0.7696
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4818 - accuracy: 0.7696
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4810 - accuracy: 0.7643
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4809 - accuracy: 0.7670
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4813 - accuracy: 0.7705
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4813 - accuracy: 0.7705
# 35/35 [==============================] - 1s 10ms/step - loss: 0.4807 - accuracy: 0.7723
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4809 - accuracy: 0.7625
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4807 - accuracy: 0.7732
# Fitness = 0.7732142806053162
# 35/35 [==============================] - 2s 20ms/step - loss: 0.4802 - accuracy: 0.7670
# 35/35 [==============================] - 2s 16ms/step - loss: 0.4804 - accuracy: 0.7688
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4800 - accuracy: 0.7679
# 35/35 [==============================] - 3s 16ms/step - loss: 0.4799 - accuracy: 0.7679
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4802 - accuracy: 0.7679
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4804 - accuracy: 0.7723
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4796 - accuracy: 0.7643
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4791 - accuracy: 0.7679
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4792 - accuracy: 0.7723
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4786 - accuracy: 0.7696
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4786 - accuracy: 0.7670
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4786 - accuracy: 0.7652
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4782 - accuracy: 0.7696
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4791 - accuracy: 0.7598
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4783 - accuracy: 0.7652
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4774 - accuracy: 0.7696
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4771 - accuracy: 0.7652
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4770 - accuracy: 0.7679
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4779 - accuracy: 0.7670
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4768 - accuracy: 0.7679
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4766 - accuracy: 0.7696
# 35/35 [==============================] - 2s 20ms/step - loss: 0.4763 - accuracy: 0.7696
# 35/35 [==============================] - 1s 19ms/step - loss: 0.4764 - accuracy: 0.7652
# 35/35 [==============================] - 1s 19ms/step - loss: 0.4767 - accuracy: 0.7705
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4760 - accuracy: 0.7696
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4759 - accuracy: 0.7634
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4753 - accuracy: 0.7661
# 35/35 [==============================] - 1s 11ms/step - loss: 0.4753 - accuracy: 0.7661
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4749 - accuracy: 0.7705
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4747 - accuracy: 0.7705
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4747 - accuracy: 0.7696
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4744 - accuracy: 0.7670
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4743 - accuracy: 0.7688
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4744 - accuracy: 0.7714
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4742 - accuracy: 0.7732
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4738 - accuracy: 0.7723
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4736 - accuracy: 0.7688
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4733 - accuracy: 0.7696
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4745 - accuracy: 0.7714
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4738 - accuracy: 0.7705
# Generation = 4
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4726 - accuracy: 0.7732
# Accuracy    = 0.7732142806053162
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4724 - accuracy: 0.7723
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4726 - accuracy: 0.7723
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4723 - accuracy: 0.7723
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4728 - accuracy: 0.7696
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4721 - accuracy: 0.7696
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4716 - accuracy: 0.7705
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4720 - accuracy: 0.7652
# 35/35 [==============================] - 1s 15ms/step - loss: 0.4722 - accuracy: 0.7688
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4712 - accuracy: 0.7652
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4715 - accuracy: 0.7705
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4708 - accuracy: 0.7732
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4716 - accuracy: 0.7652
# 35/35 [==============================] - 2s 21ms/step - loss: 0.4703 - accuracy: 0.7670
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4701 - accuracy: 0.7714
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4706 - accuracy: 0.7759
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4711 - accuracy: 0.7661
# 35/35 [==============================] - 2s 21ms/step - loss: 0.4699 - accuracy: 0.7741
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4706 - accuracy: 0.7732
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4699 - accuracy: 0.7696
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4694 - accuracy: 0.7750
# 35/35 [==============================] - 2s 24ms/step - loss: 0.4692 - accuracy: 0.7643
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4691 - accuracy: 0.7723
# 35/35 [==============================] - 2s 21ms/step - loss: 0.4687 - accuracy: 0.7741
# 35/35 [==============================] - 2s 21ms/step - loss: 0.4691 - accuracy: 0.7750
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4683 - accuracy: 0.7750
# 35/35 [==============================] - 4s 18ms/step - loss: 0.4687 - accuracy: 0.7705
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4684 - accuracy: 0.7732
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4679 - accuracy: 0.7750
# 35/35 [==============================] - 1s 18ms/step - loss: 0.4680 - accuracy: 0.7732
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4675 - accuracy: 0.7723
# 35/35 [==============================] - 1s 13ms/step - loss: 0.4684 - accuracy: 0.7705
# 35/35 [==============================] - 1s 13ms/step - loss: 0.4685 - accuracy: 0.7714
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4684 - accuracy: 0.7759
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4675 - accuracy: 0.7705
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4681 - accuracy: 0.7679
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4667 - accuracy: 0.7696
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4668 - accuracy: 0.7741
# 35/35 [==============================] - 1s 13ms/step - loss: 0.4660 - accuracy: 0.7750
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4662 - accuracy: 0.7741
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4660 - accuracy: 0.7723
# Fitness = 0.7758928537368774
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4659 - accuracy: 0.7679
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4651 - accuracy: 0.7750
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4659 - accuracy: 0.7714
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4651 - accuracy: 0.7714
# 35/35 [==============================] - 1s 18ms/step - loss: 0.4658 - accuracy: 0.7705
# 35/35 [==============================] - 2s 20ms/step - loss: 0.4648 - accuracy: 0.7705
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4642 - accuracy: 0.7714
# 35/35 [==============================] - 1s 13ms/step - loss: 0.4643 - accuracy: 0.7705
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4645 - accuracy: 0.7732
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4642 - accuracy: 0.7723
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4644 - accuracy: 0.7714
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4642 - accuracy: 0.7714
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4643 - accuracy: 0.7714
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4633 - accuracy: 0.7768
# 35/35 [==============================] - 1s 12ms/step - loss: 0.4632 - accuracy: 0.7732
# 35/35 [==============================] - 3s 49ms/step - loss: 0.4633 - accuracy: 0.7696
# 35/35 [==============================] - 3s 26ms/step - loss: 0.4635 - accuracy: 0.7741
# 35/35 [==============================] - 2s 20ms/step - loss: 0.4634 - accuracy: 0.7705
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4625 - accuracy: 0.7714
# 35/35 [==============================] - 2s 20ms/step - loss: 0.4623 - accuracy: 0.7714
# 35/35 [==============================] - 2s 20ms/step - loss: 0.4619 - accuracy: 0.7768
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4619 - accuracy: 0.7723
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4626 - accuracy: 0.7723
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4617 - accuracy: 0.7741
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4610 - accuracy: 0.7741
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4612 - accuracy: 0.7777
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4608 - accuracy: 0.7741
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4611 - accuracy: 0.7732
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4608 - accuracy: 0.7759
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4615 - accuracy: 0.7714
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4603 - accuracy: 0.7732
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4598 - accuracy: 0.7732
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4595 - accuracy: 0.7786
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4614 - accuracy: 0.7759
# 35/35 [==============================] - 2s 21ms/step - loss: 0.4593 - accuracy: 0.7741
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4588 - accuracy: 0.7786
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4593 - accuracy: 0.7723
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4595 - accuracy: 0.7741
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4589 - accuracy: 0.7750
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4585 - accuracy: 0.7741
# Generation = 5
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4585 - accuracy: 0.7768
# Accuracy    = 0.7767857313156128
# 35/35 [==============================] - 2s 16ms/step - loss: 0.4586 - accuracy: 0.7768
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4576 - accuracy: 0.7768
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4578 - accuracy: 0.7750
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4591 - accuracy: 0.7759
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4571 - accuracy: 0.7804
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4580 - accuracy: 0.7750
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4573 - accuracy: 0.7777
# 35/35 [==============================] - 2s 21ms/step - loss: 0.4564 - accuracy: 0.7777
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4573 - accuracy: 0.7777
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4562 - accuracy: 0.7777
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4568 - accuracy: 0.7795
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4563 - accuracy: 0.7759
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4559 - accuracy: 0.7759
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4561 - accuracy: 0.7750
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4558 - accuracy: 0.7750
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4549 - accuracy: 0.7768
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4567 - accuracy: 0.7786
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4546 - accuracy: 0.7768
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4545 - accuracy: 0.7786
# 35/35 [==============================] - 1s 13ms/step - loss: 0.4546 - accuracy: 0.7821
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4548 - accuracy: 0.7768
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4540 - accuracy: 0.7795
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4537 - accuracy: 0.7777
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4538 - accuracy: 0.7759
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4535 - accuracy: 0.7786
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4550 - accuracy: 0.7839
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4526 - accuracy: 0.7759
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4530 - accuracy: 0.7786
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4528 - accuracy: 0.7795
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4525 - accuracy: 0.7821
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4523 - accuracy: 0.7839
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4521 - accuracy: 0.7750
# 35/35 [==============================] - 1s 14ms/step - loss: 0.4527 - accuracy: 0.7830
# 35/35 [==============================] - 2s 14ms/step - loss: 0.4525 - accuracy: 0.7839
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4509 - accuracy: 0.7875
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4515 - accuracy: 0.7732
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4518 - accuracy: 0.7857
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4517 - accuracy: 0.7741
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4512 - accuracy: 0.7795
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4514 - accuracy: 0.7911
# Fitness = 0.7910714149475098
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4508 - accuracy: 0.7786
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4517 - accuracy: 0.7848
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4504 - accuracy: 0.7821
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4502 - accuracy: 0.7848
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4497 - accuracy: 0.7830
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4493 - accuracy: 0.7848
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4496 - accuracy: 0.7857
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4491 - accuracy: 0.7812
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4489 - accuracy: 0.7839
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4495 - accuracy: 0.7821
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4479 - accuracy: 0.7875
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4481 - accuracy: 0.7839
# 35/35 [==============================] - 2s 26ms/step - loss: 0.4482 - accuracy: 0.7857
# 35/35 [==============================] - 2s 27ms/step - loss: 0.4474 - accuracy: 0.7812
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4473 - accuracy: 0.7857
# 35/35 [==============================] - 2s 27ms/step - loss: 0.4495 - accuracy: 0.7875
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4475 - accuracy: 0.7857
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4463 - accuracy: 0.7857
# 35/35 [==============================] - 2s 24ms/step - loss: 0.4473 - accuracy: 0.7848
# 35/35 [==============================] - 3s 27ms/step - loss: 0.4467 - accuracy: 0.7848
# 35/35 [==============================] - 2s 35ms/step - loss: 0.4459 - accuracy: 0.7857
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4456 - accuracy: 0.7848
# 35/35 [==============================] - 2s 24ms/step - loss: 0.4458 - accuracy: 0.7830
# 35/35 [==============================] - 2s 32ms/step - loss: 0.4451 - accuracy: 0.7857
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4451 - accuracy: 0.7866
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4449 - accuracy: 0.7857
# 35/35 [==============================] - 2s 14ms/step - loss: 0.4448 - accuracy: 0.7857
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4443 - accuracy: 0.7875
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4455 - accuracy: 0.7830
# 35/35 [==============================] - 2s 17ms/step - loss: 0.4454 - accuracy: 0.7830
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4435 - accuracy: 0.7893
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4435 - accuracy: 0.7866
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4434 - accuracy: 0.7857
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4439 - accuracy: 0.7875
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4432 - accuracy: 0.7839
# 35/35 [==============================] - 2s 24ms/step - loss: 0.4428 - accuracy: 0.7884
# 35/35 [==============================] - 3s 28ms/step - loss: 0.4427 - accuracy: 0.7848
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4426 - accuracy: 0.7857
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4424 - accuracy: 0.7875
# 35/35 [==============================] - 2s 24ms/step - loss: 0.4419 - accuracy: 0.7839
# Generation = 6
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4419 - accuracy: 0.7866
# Accuracy    = 0.7866071462631226
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4417 - accuracy: 0.7848
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4411 - accuracy: 0.7839
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4408 - accuracy: 0.7893
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4410 - accuracy: 0.7857
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4404 - accuracy: 0.7857
# 35/35 [==============================] - 2s 14ms/step - loss: 0.4402 - accuracy: 0.7848
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4399 - accuracy: 0.7804
# 35/35 [==============================] - 2s 18ms/step - loss: 0.4394 - accuracy: 0.7884
# 35/35 [==============================] - 2s 33ms/step - loss: 0.4398 - accuracy: 0.7866
# 35/35 [==============================] - 2s 29ms/step - loss: 0.4398 - accuracy: 0.7902
# 35/35 [==============================] - 2s 27ms/step - loss: 0.4400 - accuracy: 0.7884
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4395 - accuracy: 0.7893
# 35/35 [==============================] - 2s 19ms/step - loss: 0.4406 - accuracy: 0.7893
# 35/35 [==============================] - 2s 29ms/step - loss: 0.4390 - accuracy: 0.7875
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4381 - accuracy: 0.7866
# 35/35 [==============================] - 2s 23ms/step - loss: 0.4377 - accuracy: 0.7884
# 35/35 [==============================] - 2s 22ms/step - loss: 0.4378 - accuracy: 0.7848
# 35/35 [==============================] - 3s 23ms/step - loss: 0.4377 - accuracy: 0.7884
# 35/35 [==============================] - 2s 27ms/step - loss: 0.4374 - accuracy: 0.7911
# 35/35 [==============================] - 2s 27ms/step - loss: 0.4372 - accuracy: 0.7902
# 35/35 [==============================] - 2s 28ms/step - loss: 0.4373 - accuracy: 0.7866
# 35/35 [==============================] - 3s 23ms/step - loss: 0.4364 - accuracy: 0.7911
# 35/35 [==============================] - 2s 24ms/step - loss: 0.4367 - accuracy: 0.7902
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4367 - accuracy: 0.7848
# 35/35 [==============================] - 7s 37ms/step - loss: 0.4358 - accuracy: 0.7937
# 35/35 [==============================] - 3s 32ms/step - loss: 0.4371 - accuracy: 0.7875
# 35/35 [==============================] - 3s 23ms/step - loss: 0.4357 - accuracy: 0.7902
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4353 - accuracy: 0.7929
# 35/35 [==============================] - 2s 28ms/step - loss: 0.4371 - accuracy: 0.7857
# 35/35 [==============================] - 2s 29ms/step - loss: 0.4350 - accuracy: 0.7893
# 35/35 [==============================] - 3s 25ms/step - loss: 0.4349 - accuracy: 0.7884
# 35/35 [==============================] - 2s 20ms/step - loss: 0.4342 - accuracy: 0.7920
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4341 - accuracy: 0.7902
# 35/35 [==============================] - 2s 36ms/step - loss: 0.4340 - accuracy: 0.7893
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4338 - accuracy: 0.7902
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4334 - accuracy: 0.7911
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4335 - accuracy: 0.7902
# 35/35 [==============================] - 3s 25ms/step - loss: 0.4346 - accuracy: 0.7857
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4338 - accuracy: 0.7937
# 35/35 [==============================] - 2s 15ms/step - loss: 0.4333 - accuracy: 0.7929
# Fitness = 0.793749988079071
# 35/35 [==============================] - 3s 25ms/step - loss: 0.4342 - accuracy: 0.7848
# 35/35 [==============================] - 2s 25ms/step - loss: 0.4319 - accuracy: 0.7911
# 35/35 [==============================] - 3s 27ms/step - loss: 0.4321 - accuracy: 0.7911
# 35/35 [==============================] - 2s 35ms/step - loss: 0.4321 - accuracy: 0.7902
# 35/35 [==============================] - 3s 26ms/step - loss: 0.4319 - accuracy: 0.7884
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4313 - accuracy: 0.7929
# 35/35 [==============================] - 3s 25ms/step - loss: 0.4307 - accuracy: 0.7911
# 35/35 [==============================] - 2s 31ms/step - loss: 0.4315 - accuracy: 0.7893
# 35/35 [==============================] - 2s 31ms/step - loss: 0.4308 - accuracy: 0.7911
# 35/35 [==============================] - 3s 36ms/step - loss: 0.4309 - accuracy: 0.7920
# 35/35 [==============================] - 3s 27ms/step - loss: 0.4299 - accuracy: 0.7937
# 35/35 [==============================] - 3s 32ms/step - loss: 0.4302 - accuracy: 0.7929
# 35/35 [==============================] - 3s 19ms/step - loss: 0.4302 - accuracy: 0.7964
# 35/35 [==============================] - 2s 26ms/step - loss: 0.4300 - accuracy: 0.7991
# 35/35 [==============================] - 2s 34ms/step - loss: 0.4293 - accuracy: 0.7955
# 35/35 [==============================] - 3s 22ms/step - loss: 0.4292 - accuracy: 0.7929
# 35/35 [==============================] - 3s 22ms/step - loss: 0.4297 - accuracy: 0.7884
# 35/35 [==============================] - 3s 31ms/step - loss: 0.4286 - accuracy: 0.7929
# 35/35 [==============================] - 2s 30ms/step - loss: 0.4293 - accuracy: 0.7911
# 35/35 [==============================] - 2s 28ms/step - loss: 0.4299 - accuracy: 0.7946
# 35/35 [==============================] - 3s 24ms/step - loss: 0.4282 - accuracy: 0.7902
# 35/35 [==============================] - 2s 29ms/step - loss: 0.4275 - accuracy: 0.7955
# 35/35 [==============================] - 2s 24ms/step - loss: 0.4280 - accuracy: 0.7893
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4272 - accuracy: 0.7911
# 35/35 [==============================] - 2s 33ms/step - loss: 0.4274 - accuracy: 0.7920
# 35/35 [==============================] - 3s 28ms/step - loss: 0.4278 - accuracy: 0.7893
# 35/35 [==============================] - 2s 33ms/step - loss: 0.4274 - accuracy: 0.7875
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4270 - accuracy: 0.7946
# 35/35 [==============================] - 2s 33ms/step - loss: 0.4270 - accuracy: 0.7911
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4271 - accuracy: 0.7964
# 35/35 [==============================] - 3s 41ms/step - loss: 0.4254 - accuracy: 0.7929
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4260 - accuracy: 0.7982
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4259 - accuracy: 0.7964
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4257 - accuracy: 0.7973
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4251 - accuracy: 0.7982
# 35/35 [==============================] - 3s 31ms/step - loss: 0.4251 - accuracy: 0.8000
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4254 - accuracy: 0.7973
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4268 - accuracy: 0.7982
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4253 - accuracy: 0.7955
# 35/35 [==============================] - 3s 32ms/step - loss: 0.4244 - accuracy: 0.7964
# Generation = 7
# 35/35 [==============================] - 2s 36ms/step - loss: 0.4245 - accuracy: 0.7955
# Accuracy    = 0.7955357432365417
# 35/35 [==============================] - 3s 31ms/step - loss: 0.4240 - accuracy: 0.8018
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4245 - accuracy: 0.8009
# 35/35 [==============================] - 3s 31ms/step - loss: 0.4242 - accuracy: 0.7955
# 35/35 [==============================] - 3s 31ms/step - loss: 0.4239 - accuracy: 0.7929
# 35/35 [==============================] - 3s 38ms/step - loss: 0.4236 - accuracy: 0.7964
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4231 - accuracy: 0.7982
# 35/35 [==============================] - 2s 35ms/step - loss: 0.4238 - accuracy: 0.7991
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4238 - accuracy: 0.7929
# 35/35 [==============================] - 3s 26ms/step - loss: 0.4237 - accuracy: 0.7946
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4224 - accuracy: 0.8027
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4224 - accuracy: 0.7973
# 35/35 [==============================] - 3s 33ms/step - loss: 0.4222 - accuracy: 0.7991
# 35/35 [==============================] - 4s 45ms/step - loss: 0.4220 - accuracy: 0.7937
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4214 - accuracy: 0.7973
# 35/35 [==============================] - 3s 36ms/step - loss: 0.4217 - accuracy: 0.7929
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4219 - accuracy: 0.7911
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4217 - accuracy: 0.7991
# 35/35 [==============================] - 3s 35ms/step - loss: 0.4211 - accuracy: 0.7973
# 35/35 [==============================] - 3s 39ms/step - loss: 0.4208 - accuracy: 0.7991
# 35/35 [==============================] - 3s 33ms/step - loss: 0.4219 - accuracy: 0.8027
# 35/35 [==============================] - 2s 38ms/step - loss: 0.4214 - accuracy: 0.8018
# 35/35 [==============================] - 2s 38ms/step - loss: 0.4200 - accuracy: 0.8036
# 35/35 [==============================] - 3s 31ms/step - loss: 0.4206 - accuracy: 0.8045
# 35/35 [==============================] - 3s 43ms/step - loss: 0.4213 - accuracy: 0.8000
# 35/35 [==============================] - 3s 46ms/step - loss: 0.4194 - accuracy: 0.8036
# 35/35 [==============================] - 4s 49ms/step - loss: 0.4208 - accuracy: 0.8018
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4192 - accuracy: 0.8054
# 35/35 [==============================] - 3s 28ms/step - loss: 0.4194 - accuracy: 0.8054
# 35/35 [==============================] - 3s 48ms/step - loss: 0.4191 - accuracy: 0.8009
# 35/35 [==============================] - 3s 41ms/step - loss: 0.4194 - accuracy: 0.7991
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4193 - accuracy: 0.8027
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4191 - accuracy: 0.8062
# 35/35 [==============================] - 3s 38ms/step - loss: 0.4206 - accuracy: 0.8018
# 35/35 [==============================] - 3s 40ms/step - loss: 0.4188 - accuracy: 0.7982
# 35/35 [==============================] - 3s 44ms/step - loss: 0.4180 - accuracy: 0.8071
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4190 - accuracy: 0.7982
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4185 - accuracy: 0.8071
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4175 - accuracy: 0.8054
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4188 - accuracy: 0.8054
# 35/35 [==============================] - 2s 39ms/step - loss: 0.4173 - accuracy: 0.8071
# Fitness = 0.8071428537368774
# 35/35 [==============================] - 4s 53ms/step - loss: 0.4169 - accuracy: 0.8027
# 35/35 [==============================] - 3s 52ms/step - loss: 0.4170 - accuracy: 0.8071
# 35/35 [==============================] - 3s 29ms/step - loss: 0.4174 - accuracy: 0.8071
# 35/35 [==============================] - 3s 32ms/step - loss: 0.4168 - accuracy: 0.8045
# 35/35 [==============================] - 13s 36ms/step - loss: 0.4171 - accuracy: 0.8089
# 35/35 [==============================] - 4s 32ms/step - loss: 0.4163 - accuracy: 0.8045
# 35/35 [==============================] - 3s 30ms/step - loss: 0.4165 - accuracy: 0.8000
# 35/35 [==============================] - 2s 37ms/step - loss: 0.4166 - accuracy: 0.8045
# 35/35 [==============================] - 3s 49ms/step - loss: 0.4167 - accuracy: 0.8089
# 35/35 [==============================] - 2s 39ms/step - loss: 0.4158 - accuracy: 0.8062
# 35/35 [==============================] - 3s 31ms/step - loss: 0.4155 - accuracy: 0.8080
# 35/35 [==============================] - 3s 35ms/step - loss: 0.4159 - accuracy: 0.8107
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4160 - accuracy: 0.8080
# 35/35 [==============================] - 3s 35ms/step - loss: 0.4161 - accuracy: 0.8062
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4160 - accuracy: 0.8036
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4159 - accuracy: 0.8125
# 35/35 [==============================] - 3s 32ms/step - loss: 0.4147 - accuracy: 0.8062
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4159 - accuracy: 0.8107
# 35/35 [==============================] - 3s 35ms/step - loss: 0.4143 - accuracy: 0.8098
# 35/35 [==============================] - 3s 46ms/step - loss: 0.4155 - accuracy: 0.8062
# 35/35 [==============================] - 3s 32ms/step - loss: 0.4157 - accuracy: 0.8080
# 35/35 [==============================] - 3s 36ms/step - loss: 0.4148 - accuracy: 0.8107
# 35/35 [==============================] - 3s 52ms/step - loss: 0.4138 - accuracy: 0.8062
# 35/35 [==============================] - 3s 43ms/step - loss: 0.4139 - accuracy: 0.8116
# 35/35 [==============================] - 4s 39ms/step - loss: 0.4141 - accuracy: 0.8071
# 35/35 [==============================] - 4s 43ms/step - loss: 0.4131 - accuracy: 0.8125
# 35/35 [==============================] - 3s 34ms/step - loss: 0.4133 - accuracy: 0.8107
# 35/35 [==============================] - 3s 33ms/step - loss: 0.4139 - accuracy: 0.8036
# 35/35 [==============================] - 4s 44ms/step - loss: 0.4134 - accuracy: 0.8134
# 35/35 [==============================] - 4s 45ms/step - loss: 0.4131 - accuracy: 0.8161
# 35/35 [==============================] - 4s 39ms/step - loss: 0.4134 - accuracy: 0.8107

# %%
solution, solution_fitness, sol_idx = ga_instance.best_solution()

# %%
# Best solution display
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Best fitness value reached after {best_solution_generation} generations.".format(best_solution_generation=ga_instance.best_solution_generation))

# %%
best_solution_weights = pygad.kerasga.model_weights_as_matrix(model=nn_model, weights_vector=ga_instance.best_solution()[0])
nn_model.set_weights(best_solution_weights)

# %%
# Plot fitness over generations
ga_instance.plot_fitness(title= "PyGad/Keras Generation vs. Fitness")

# %% [markdown]
# # Analysis of GA Instance

# %% [markdown]
# We can see the accuracy and fitness scores through each of our 10 generations above. No two accuracy scores or fitness scores are the same, but there is some random fluctuations of improvements and regressions in our scores. These discrepancies occur in such a manner because 10 generations is not enough time for this genetic algorithm to train our neural network. Running far more generations would increase our model fitness/accuracy because the algorithm would cover far more of the search space. It is a great sign that these values are changing though. This confirms that our model is undergoing learning, and the particular genetic algorithm instance is doing it's job.
#
# I would guess that the high crossover probability paired with uniform crossover type scrambles and changes the weight solutions significantly after each generation, which could explain the limited improvement in our predictions as well.
#
# Training this model also took far longer than the evolutionary strategy assignment. The population size is far larger and the weights undergo both crossover AND mutation compared to just adaptive mutation in our last assignment.

# %%
# Use GA and custom weights to predict using our model
# Training predictions
training_predictions = pygad.kerasga.predict(model=nn_model,
                                    solution=solution,
                                    data=X_train)

# Testing predictions
testing_predictions = pygad.kerasga.predict(model=nn_model,
                                    solution=solution,
                                    data=X_test)

# %%
test_loss, test_accuracy = nn_model.evaluate(X_test, Y_test)
print('Test accuracy:', test_accuracy)

# %%
train_loss, train_accuracy = nn_model.evaluate(X_train, Y_train)
print('Train accuracy:', train_accuracy)

# %%
# Make confusion matrices
confusion_matrix_test = confusion_matrix(Y_test, testing_predictions.round()) 
confusion_matrix_train = confusion_matrix(Y_train, training_predictions.round())

# %%
# Visualize monfusion matrices using seaborn like other assignments
import seaborn as sns

# Test data
sns.heatmap(confusion_matrix_test, annot=True)
plt.title('Confusion Matrix Test Data')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# Train data
sns.heatmap(confusion_matrix_train, annot=True)
plt.title('Confusion Matrix Train Data')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# # Summary/Report

# %% [markdown]
# Genetic algorithms are ideal for complex optimization problems such as this neural network, binary classification problem. Some of the main takeaways and lessons I've learned from this assignment involve computational resoures and hyperparameter instantiation. It's extremely hard to visualize and choose what paramters and hyperparameters are necessary for maximum learning and optimization. Playing around with different values, selection types, population sizes, and mutations all have profound affects on our genetic algorithm which was visualized perfectly in this assignment. Another big takeaway for me was the difference in computation time. Training and running my neural network with my GA took substantially longer than the previous assignment we did with an ES. The population size and amount of operations that happen in this GA take a major toll on runtime and computational effort.
#
# Visualizing the improvement through the genetic algorithm make it easy for me to see it's effectiveness. We can see this preformance through our confusion matrices and our generational output. Accuracy and fitness scores improved after every generation, and our confusion matrices have both improved over our last assignments corresponding matrices.
